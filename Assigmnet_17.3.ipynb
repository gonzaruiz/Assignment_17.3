# %%
#To balls are drawn at random in sucession without replacement from an urn containing 4 red balls and 6 black balls.
#Find the probabilities of all the possible outcomes.


------


4 R, 6 B


--------

P(first drawn both balls are Red) = p(R) * p(R)
                            = 4/10 * 4/10
                            = 2/5 * 2/5 = 4/25 = 16%
        
P(second drawn both balls are Red) = p(R) * p(R)
                             = 2/8 * 2/8
                             = 1/4 * 1/4 = 1/16 = 6.25%
        
-------

        
P(first drawn both balls are black) = p(R) * p(R)
                              = 6/10 * 6/10
                              = 3/5 * 3/5 = 15/25 = 60%
        
P(second drawn both balls are black) = p(B) * p(B)
                               = 4/8 * 4/8
                               = 1/2 * 1/2 = 1/4 = 25%
        
P(3rd both drawn balls are black)    = p(B) * p(B)
                               = 2/6 * 2/6
                               = 1/3 * 1/3 = 1/9 = 11.11% 
        
----------        

        
p(first drawn 1 ball Red, 1 ball Black) = p(R) * p(B)
                                     = 4/10 * 6/10
                                     = 2/5 * 3/5 = 6/25 = 24%
        
p(second drawn 1 ball Red, 1 ball Black) = p(R) * p(B)
                                     = 3/8 * 5/8
                                     = 3/8 * 5/8 = 15/64 = 23,43%       

        
p(3erd drawn 1 ball Red, 1 ball Black) = p(R) * p(B)
                                     = 2/6 * 4/6
                                     = 1/3 * 2/3 = 2/9 = 22,22%
        
p(4rd drawn 1 ball Red, 1 ball Black) = p(R) * p(B)
                                     = 1/4 * 3/4
                                     = 1/4 * 3/4 = 3/16 = 18.75%         
        
        
p(5rd drawn 1 ball black, 1 ball Black) = p(B) * p(B)
                                     = 2/2 * 2/2
                                     = 1/1 * 1/1 = 1/1 = 100%   
        
------------------
